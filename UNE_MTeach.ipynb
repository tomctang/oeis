# %% [markdown]
# APA 7th edition reference
#
# Lantite Math - not hard, must be **careful reading**
# - 3 real tests in School Support site
#
# [APST](https://www.aitsl.edu.au/standards)
#
# [ACARA (National Curriculum) ](https://www.acara.edu.au/curriculum)

# %% [markdown]
# ### MTeach & GTPA & PREXUS(PrEx Nexus)

# %% [markdown]
# 核心邏輯鏈：
# - 核心目標:學生必須證明自己的教學能滿足 AITSL（澳洲教學與學校領導協會）的 APST (澳洲教師專業標準)。
# - 通過「分析數據」和「深度反思」，向評估者證明：**「我的教學設計是合理的，我的教學實施是有效的，且學生的學習成果證明了這一點。」**
# - **建設性對齊 (Constructive Alignment)**
# - 澳洲的教師認證非常強調 **"Data-driven decision making (數據驅動的決策)"**，
# - 從 Unit Plan 到 GTPA ，**Evidence-based practice** 是貫穿所有產出層級的最高指導原則。
#     - **Unit Plan** 解決了 **"教什麼 (What)"** 和 **"怎麼教 (How)"** 的問題；
#     - **GTPA** 則是在 Unit Plan 的基礎上，加入了 **"對誰教 (Who - Context)"**、**"教得如何 (Impact - Assessing)"** 以及 **"為什麼這樣教 (Why - Reflecting)"** 的完整閉環。
#
# 1. **Lesson Plan (單節課教案)**：微觀執行層. 這是教學的基石，通常要求針對 40-60 分鐘的單節課進行精細設計。核心內容：
#     *   **Learning Intentions & Success Criteria (學習意圖與成功標準)**：明確告知學生「這節課要學什麼」以及「如何算學會了」（常使用 WALT - We Are Learning To / WILF - What I'm Looking For）。
#     *   **Curriculum Links (課綱連結)**：精準對接澳洲國家課綱 (ACARA) 或各州課綱 (如 VIC 的 VELS/VCAL, NSW 的 NESA) 的 Content Descriptors。
#     *   **Lesson Sequence (教學流程)**：
#         *   *Hook/Warm-up* (引起動機)
#         *   *Explicit Teaching* (直接教學/概念講解)
#         *   *Guided/Independent Practice* (引導與獨立練習)
#         *   *Plenary/Reflection* (總結與反思)
#     *   **Formative Assessment (形成性評量)**：如 Exit tickets, Mini-whiteboards, Thumbs up/down。
#     *   **Resources (教學資源)**。
# 2. **Unit Plan / Learning Sequence (單元教案/學習序列)**：中觀主題層. 將多節課串聯成一個有邏輯的學習主題（通常為期 4 到 8 週）。這是 GTPA 中「Planning（規劃）」階段的核心產出:
#     *   **Overarching Inquiry Question (核心探究問題)**：引導整個單元的驅動問題。
#     *   **Scope and Sequence (範圍與序列)**：將單元目標拆解到每週/每節課的進度表。
#     *   **Cross-Curriculum Priorities (跨課程優先事項)**：必須融入澳洲課綱的三大核心（例如：原住民歷史與文化、澳洲與亞洲的連結、永續發展）。
#     *   **General Capabilities (通用能力)**：如批判性思考、ICT能力、個人與社會能力。
#     *   **Summative Assessment Task (總結性評量任務)**：單元結束時的重大任務（如專題報告、演講、展覽），並附有 **Rubric (評分規準)**。
# 3. **Differentiation & Inclusion Plan (差異化與融合教育設計)**：學生需求層 Equity. 核心內容：
#     *   **EAL/D (英語為第二語言或方言) 學生**：提供鷹架 (Scaffolding)、視覺輔助、詞彙表。
#     *   **NCCD (全國一致殘疾學生定義)**：針對自閉症、ADHD、學習障礙等學生的合理調整 (Reasonable Adjustments)，如延長考試時間、提供安靜空間。
#     *   **Gifted and Talented (資優生)**：提供延伸任務 (Extension tasks) 或更深度的探究。
#     *   **UDL (通用學習設計)**：確保教學素材具備多種呈現、表達和參與的方式。
# 4. **Reflective ePortfolio (反思電子作品集)**：理論與專業成長層. 要求蒐集大學期間的課程作業產出，並用學術理論進行反思。核心內容：
#     *   **對標 APST (澳洲教師專業標準)**：必須針對 7 大標準、37 個細項（分為 Graduate, Proficient, Highly Accomplished, Lead 四個層級，畢業生需達到 **Graduate 層級**）提供證據（如教案、學生作業照片、教學影片）。
#     *   **Critical Reflection (批判性反思)**：常用 Gibbs 或 Schön 的反思模型，探討「我為什麼這樣教？效果如何？如果重來我會怎麼做？這與Vygotsky或Piaget的理論有何關聯？」
# 5. **Professional Experience Report (實習評估報告)**：現場實務層. 3 到 4 次實習（從觀察、助教到全職接課）。
#     *   **University Supervisor Report (大學督導報告)**：大學派來的教授到教室觀課並評分。
#     *   **Mentor Teacher Feedback (指導教師回饋)**：實習學校的帶班老師給予的日常回饋。
#     *   **Professional Engagement (專業參與)**：參與教師會議、家長會、課外活動 (Extracurricular activities) 的紀錄。

# %% [markdown]
# 第一層：課堂執行層 (Micro-level Implementation)
# 這是實習初期和日常教學中最基礎的產出，聚焦於單節課的落地。
#
# *   **Lesson Plan (單節課教案)**
#     *   **內容**：具體的 40-60 分鐘教學流程。包含：導入 (Hook)、直接教學 (Direct Instruction)、引導練習 (Guided Practice)、獨立練習 (Independent Practice)、結尾 (Closure)。
#     *   **核心要素**：明確的教學意圖 (Learning Intention) 和 成功標準 (Success Criteria)；具體的提問策略 (Questioning strategies)；時間分配。
# *   **Teaching Resources & Materials (教學資源)**
#     *   **內容**：課件 (Slides)、工作紙 (Worksheets)、多媒體素材、實體教具等。
# *   **Formative Assessment Tools (形成性評估工具)**
#     *   **內容**：用於課堂即時反饋的工具，如 Exit tickets (出門條)、Mini-whiteboards (小白板) 記錄、觀察核對表 (Observation checklists)、Thumbs up/down 等。
#
# 第二層：單元設計層 (Meso - Unit Plan & Rubrics Design) —— **核心樞紐**
# 這一層級是連接單節課與宏觀課程的橋樑，也是 GTPA 的核心基礎。
#
# *   **Unit of Work / Unit Plan (單元計劃)**
#     *   **定位**：通常包含 **3-5 節連貫的課**，圍繞一個特定的主題或技能展開。這是 GTPA 要求提交的核心文件。
#     *   **完整內容包含**：
#         1.  **Syllabus/Curriculum Links (課程大綱連結)**：明確對應澳洲國家課程 (Australian Curriculum) 或各州大綱 (如 NSW NESA, VIC VCAA) 的具體 Content Descriptions (內容描述) 和 Achievement Standards (成就標準)。
#         2.  **Contextual Considerations (背景考量)**：該班級的整體學情、 prior knowledge (先備知識)。
#         3.  **Differentiation & Inclusion (差異化與融合教育)**：針對不同需求學生（如 EAL/D 英語非母語學生、GATS 原住民、Gifted & Talented 資優生、SEN 特殊教育需求學生）的具體調整策略 (Adjustments)。
#         4.  **Teaching and Learning Sequence (教學序列)**：3-5 節課的宏觀流程概述，每節課的重點、教學法 (Pedagogy) 和使用的資源。
#         5.  **Assessment Plan (評估計劃)**：明確指出哪一節課進行形成性評估，哪一節課進行總結性評估 (Summative Assessment)。
# *   **Summative Assessment Task (總結性評估任務)**
#     *   **內容**：單元結束時的正式評估（如測驗、 essay、項目報告、口頭演講）。
#     *   **配套文件**：必須包含 **Marking Rubric / Criteria sheet (評分量規)**，明確區分 A/B/C/D 或 Excellent/Satisfactory/Needs Improvement 的具體表現標準。
#
# 第三層：背景與學情分析層 (Macro-level Context)
# 在進行任何教學設計前，必須對環境和對象進行深度剖析，這是 GTPA 的起點。
#
# *   **School Context Profile (學校背景檔案)**
#     *   **內容**：學校的社會經濟地位 (ICSEA value)、地理位置、辦學理念、特殊項目、社區資源等。
# *   **Class Profile (班級檔案)**
#     *   **內容**：班級人數、性別比例、整體學術水平、行為管理策略、班級動態。
# *   **Focus Student Profiles (焦點學生檔案)**
#     *   **內容**：GTPA 要求選取 **3 名焦點學生**（通常代表高、中、低不同學術水平，或包含特殊需求學生）。需詳細記錄他們的學習優勢、挑戰、興趣、Iep (個別化教育計劃，若有) 等。
#
# 第四層：證據收集與數據分析層 (Evidence & Data Analysis)
# 澳洲教師教育極度看重「用數據說話」，這一層級是證明教學有效性的關鍵。
#
# *   **Student Work Samples (學生作品樣本)**
#     *   **內容**：收集焦點學生在總結性評估任務中的實際作品（需隱去真實姓名，用 Student A/B/C 代替）。通常要求提供 Pre-assessment (前測) 和 Post-assessment (後測) 的對比。
# *   **Assessment Data Records (評估數據記錄)**
#     *   **內容**：全班成績分佈圖表、焦點學生的具體得分及在量規 (Rubric) 上的具體表現位置。
# *   **Feedback Records (反饋記錄)**
#     *   **內容**：教師提供給學生的書面或口頭反饋記錄，以及**學生對反饋的回應/改進證據**（這在 AITSL 標準中非常重要，證明反饋被使用了）。
#
# 第五層：終極綜合產出 —— GTPA (Graduate Teacher Performance Assessment)
# **“Graduate Teacher Performance Assessment”（GTPA，毕业生教师绩效评估）** **最後一次教育實習**期間必須完成一份 ****綜合檔案袋 (Portfolio/Report)「證明你具備獨立執教能力」的完整數據與反思報告**，**如果 GTPA 不及格，学生将无法完成学位。** NESA要求申请者必须达到《澳大利亚教师专业标准》Australian Professional Standards for Teachers, APST，才能顺利申请到正式的教师注册资格（Teacher Registration）
#
# 考核形式与内容: 独立完成一个完整的“教学、学习与评估循环”（Teaching, Learning and Assessment Cycle）。 Portfolio 通常包含5个核心部分：
#
# 1. Context (情境脈絡分析)
# *   **內容**：整合第三層的內容。分析實習學校的社區背景、學校數據（如 NAPLAN 成績、出勤率）、班級概況，以及 3 名焦點學生的詳細學情分析。
# *   **班級分析**：詳細描述你所教班級的學生組成（EAL/D 比例、特殊需求學生、原住民學生、班級學習風氣）。
# *   **目的**：證明你的後續教學設計是「基於學生數據與真實情境」而量身定制的，了解教學環境，並能識別學生的多樣性需求 (對應 AITSL 標準 1: Know students and how they learn)。
#
# 2. Planning (教學規劃)设计一个连贯的教学单元（通常包含 3 到 5 节课的教案），明确学习目标，并说明如何根据学生的不同背景和能力进行差异化教学。
# *   **內容**：提交上述的 **Unit Plan (單元教案3-5節課)**。
# *   **要求**：必須明確指出你如何根據第 1 點的「Context」來調整這個單元計畫。你如何設計評量？如何融入跨課程優先事項？
# *   **目的**：證明實習生能根據課程大綱和學情，設計連貫、有邏輯且包含差異化教學的單元計劃 (對應 AITSL 標準 2: Know the content and how to teach it; 標準 3: Plan for and implement effective teaching and learning)。
#
# 3. Teaching (教學執行與證據)
# *   **內容**：證明你真的在課堂上執行了這個計畫。
# *   **產出**：
#     *   教學影片片段（需取得家長/學校同意）。
#     *   指導教師 (Mentor) 的觀課紀錄表。
#     *   課堂上的師生互動照片、使用的教材、白板記錄。
#
# 4. Assessing (評量與數據分析) 收集至少 2-3 名不同学习水平（如高分、中等、需要帮助的学生）的**真实作业样本**，并给出你的批改和反馈。
# *   **內容**：整合第四層的內容。展示學生的學習成果。這是 GTPA 最看重的部分之一：**你如何證明學生「真的學到了」？** —— **GTPA 的重中之重**
# *   **產出**：
#     *   **Pre-assessment (前測) 與 Post-assessment (後測) 數據對比**：用圖表展示全班學生的進步幅度。
#     *   **Student Work Samples (學生作業樣本)**：挑選高、中、低 (High, Medium, Low) 三份學生作品，指出他們的理解誤區或優勢。
#     *   **反饋與下一步**：記錄你給這 3 名學生的具體反饋**Feedback**（需符合 Hattie 的可見學習理論或 Growth Mindset 概念），並提出針對性的「下一步教學建議 (Next steps for learning)」。
#     *   **Data Analysis**：分析哪些教學策略有效？哪些學生沒有達標？為什麼？
#     *   **目的**：證明實習生能設計並使用有效的評估工具, 能解讀學生數據，並利用數據來改進教學 (對應 AITSL 標準 5: Assess, provide feedback and report on student learning)。
#
# 5. Reflecting (專業反思) 基于收集到的学生作业数据，分析自己的教学效果，反思哪些教学策略有效，哪些无效，并提出后续教学的调整方案。
# *   **內容**：綜合上述整個單元的教學過程，写深度的學術反思报告。必須明確引用 AITSL Graduate Standards，舉例說明自己的教學如何影響了學生的學習，並提出自己未來作為新教師的專業發展方向 (對應 AITSL 標準 6: Engage in professional learning)。
# *   **核心問題**：
#     *   你的教學對學生的學習產生了什麼具體影響 (Impact on student learning)？
#     *   作為一名新手教師，你發現了自己的哪些優勢與盲點？
#     *   你未來的專業發展計畫 (Professional Learning Plan) 是什麼？你需要尋求哪些資深教師或專家的幫助？
#
# 给就读学生的建议
# 1.  **尽早沟通：** 开学初就与你的大学导师（University Supervisor）和实习学校的指导老师（Mentor Teacher）沟通 GTPA 的具体要求。
# 2.  **争取连续授课：** 确保你有机会连续教授一个完整的单元（3-5节课），而不是零散地代课，这样才能体现教学的连贯性和对学生学习的持续影响。
# 3.  **注意收集素材：** 在实习期间务必保留好学生的作业样本、评估数据和课堂照片，这些都是撰写 GTPA 报告不可或缺的核心证据。
#
# GTPA 的基石：
# 1.  **Lesson Observation Records (聽課與授課觀察記錄)**：由大學導師 (University Supervisor) 或學校指導老師 (Mentor Teacher) 填寫的觀察反饋表。
# 2.  **Professional Experience Reports (實習成績單)**：指導老師根據 AITSL 標準對實習生進行的期末評分與評語。
# 3.  **eAPe (electronic Portfolio of Evidence / 電子檔案袋)**：許多大學將教案、反思、學生作品、大學作業等上傳至此系統，直接映射到 AITSL 的 7 大領域標準，畢業時作為教師註冊的佐證材料。
#
# PrEx: Arrange My School Placement

# %% [markdown]
# ### EDLT500 Planning for Effective Learning

# %% [markdown]
# #### Contents

# %% [markdown]
# - [500 Schedule - Due](https://mylearn.une.edu.au/mod/book/view.php?id=3537459)
# - 看7章的Book(网页) - **Kristy said: focus on concepts developed in the lectures, tutorials and the weekly formative discussion forums (看resources纯粹浪费时间，尤其wk3)**
# - PrExConnex
#   - task 1 - Plan and evaluate a lesson sequence
#   - EDLT500 directly go to EDUC550 (20Days PrEx) when you planned a detailed learning sequence
#
# Learning outcomes
# - develop learning theory into a coherent and justified teaching philosophy and link it to the elements of the Australian Professional Standards for Teachers as a framework for ongoing professional learning (Graduate Teaching Standard - GTSD 1.2.1, 6.1.1);
# - apply knowledge and understanding of the stages of child and adolescent development to meet the specific learning needs of students across the full range of abilities (GTSD 1.1.1, 1.2.1, 1.6.1);
# - apply the teaching cycle to plan effective teaching and learning experiences, including assessment, that promote higher-order critical thinking in learners, including the use of verbal and non-verbal communication strategies (GTSD 1.5.1, 3.1.1, 3.2.1, 3.3.1, 3.5.1, 3.6.1, 5.1.1, 5.2.1);
#     - GTSD 3.1.1 Set learning goals that provide achievable challenges for students of varying abilities and characteristics.
#     - GTSD 5.1.1 Demonstrate understanding of assessment strategies, including informal and formal, diagnostic, formative and summative approaches to assess student learning.
# - apply a range of strategies to interpret assessment data and modify teaching practice (GTSD 5.1.1, 5.3.1, 5.4.1).

# %% [markdown]
# wk1 - Learning Theories
# - **Constructivist learning**(our course): learning is a co-production involving student agency in the building of knowledge and understanding. Your role as a student/learner/pre-service teacher in this unit and tutorials is one of working out which theories you think will help you become the sort of teacher you would like to be, then examining the practical implications of your decisions
# - **Transformative Learning Theory**: learning as a developmental process that builds upon prior learning and knowledge. Within this is the importance of critical reflection on what one knows and on what one is learning in the moment.
#   - Transformative learning theory is heavily influenced by constructivist principles, as both share the core idea that learners actively create and interpret meaning from their experiences. While constructivism focuses generally on how knowledge is built, transformative learning specifically focuses on changing deeply held beliefs and worldviews.
# - Jean Piaget
#     - Theory of Cognitive Development (Constructivism)
# - VYGOTSKY’S
#     - Sociocultural Theory of Cognitive Development (Constructivism)
#     - Zone of Proximal Development (ZPD)
#     - SCAFFOLDING / ASSISTED LEARNING
# - Teaching & Learning Cycle 教/学周期
# - McInerney, D. M., & Putwain, D. W. (2017). Chapter 5: Cognition and cognitive development: Infancy to late childhood. In Developmental and educational psychology for teachers: An applied approach (2nd ed., pp. 91–121). Routledge.
#     - This chapter gives you an outline of cognitive development, drawing from the work of Jean Piaget and Lev Vygotsky.
# - Groundwater Smith,S.,  Ewing, R., & Le Cornu, R. (2015). Chapter 3 (pages 50 -75) In Teaching Challenges and Dilemmas
#     - introduces the idea of inclusion and the need to cater for students with disabilities in your classroom. Teaching for diversity requires you to understand differentiation.
# - **Theory of Learner Styles** is an outdated perspective.
#
#
# wk2 - HITS PCK and Lesson Plan (lesson planning / planning lessons备课)
# - High Impact Teaching Strategies (HITS)
# - Pedagogical Content Knowledge (PCK)
# - Learner Agency
#
# wk3 - Teaching Strategies: Quality Teaching Model Blooms Taxonomy, Breadth & Depth of Lesson Plan
# - ?
#
# wk4 - Teaching Strategies: Cooperative Learning, Differentiation Graphic Organisers
# - ?

# %% [markdown]
# wk5-6 - Lesson Sequence Assessment: Student Focused Assessment, Data and Reporting
# - ?
#
# wk7 - Questioning and Explaining
# - ?
#
# wk8 - Child/Adolescent Development and its Relationship to Learning
# - ?

# %% [markdown]
# #### Assessments

# %% [markdown]
# - Assessment 1: Two online Quizzes, Due 26 July & 6 Sep - Once chance 60 min
#     - Quiz 1: lectures, tutorials, and required readings Weeks 1-4. All 20 items in 10 (multiple choice, matching, fill in the blank, true/false).
#     -
#     - Quiz 2: lectures, tutorials, and required readings Weeks 5-8. All 20 items in 10 (multiple choice, matching, fill in the blank, true/false).
# - Assessment 2: Learning Sequence - see docx. Due 9 August
# - Assessment 3: Written response - see docx. Due 13 Sep

# %%
1 Preliminary exercise

1. Your definition of a 'good teacher'.
- Who can give me a dream, inspiring, and reasoning. 

2. Your definition of a 'good assessment'.
- A fair fight.

3. How would you define intelligence? Is it innate? Can it change?
- Intelligence is partly innate, but willing to and can be changed by interactions with outside environments. 
- Intelligence is defined by the willing and capacity to exchange resources with the world outside oneself. 

4. What actually happens when we learn something?
- It means something new connected to our inner world or mind set. 

5. What kinds of questions or type of questioning helps others to learn?     
- Inspiring and inner-connected.

6. How do you know when you've been given a good explanation - what does it involve?
- Solid causality. 

7. Do you think it is better to learn individually or in groups? Why?
- Individually. All learning are essentially self-learning. It is like self-tuning or self-training AI.

# %% [markdown]
# ### EDUC503 Cultural Diversity – EAL/D Students

# %% [markdown]
# #### Contents

# %% [markdown]
# [503 Schedule - Due](https://mylearn.une.edu.au/mod/book/view.php?id=3525164)
#
# Two problems: culturally and linguistically diverse/inclusive
# - multicultural education, anti-racism, and EAL/D policies
# - Solution: Culturally Relevant Pedagogy (CRP)
#
# Topic 1: Multicultural Education - What have immigration, racism amd multiculturalism got to do with teaching?
# - Multiculturalism: the policy or process whereby the distinctive identities of the cultural groups within a society are maintained or supported.1
# - Multicultural Education: An approach designed to actualise educational equality for students from diverse racial, ethnic, cultural social-class and linguistic groups.2
#
# Topic 2: EAL/D Students - What does it mean to be 'other' in schools?
#
# Topic 3: Culturally Relevant Pedagogy (CRP)
#
# Topic 4: CRP in Action: What is 'Culture' Anyway?
#
# Topic 5: CRP in Action: Linguistic Power and Diversity
#
# Topic 6: CRP in Action: Working with EAL/D students (1)
#
# Topic 7: CRP in Action: Working with EAL/D students (2)
#
# Topic 8: 'Reality Pedagogy' - Anti-racism policy and strategy in the classroom and beyond

# %% [markdown]
# #### Assessment 1A+1B(10%+40%) 5 posts -> a combined PDF 最终作业

# %% [markdown]
# *1A* - Autobiographical Essay Topic 1 post (400 words/no references required). Relates to GTSD: 1.1.1, 1.3.1, 1.4.1, 1.5.1, 2.4.1, 4.1.1, 4.4.1, 7.1.1, 7.2.1
# - before doing any unit readings, just document your current understanding of issues around cultural diversity in the classroom, so you can draw on your own past schooling experiences to contextualise your discussion. 第一步： 回顾你过去的求学经历，学校是如何应对学生（包括你）带入课堂的各种形式的多元性（例如文化、种族、宗教、社会经济和语言差异）的。可以参考以下问题：
#     - 你的同学中是否有与众不同的？或者你与其他同学有何不同？他们/你有哪些不同之处？ 你的学校和同学是如何看待这种差异的？
#     - 你认为你的学校和老师是否妥善处理了这种差异？如果没有，那些承担课堂教学职责和/或学校领导角色的人应该如何更好地处理这种差异问题？
# - 第二步： 假设你被任命到一所学校任教，这所学校有很多学生来自不同的文化、种族、社会经济和语言背景，其中许多背景与你自身不同。假设你有三到五名新近移民的学生，他们母语流利，但在英语教学方面存在很大困难。请讨论在这个假想的课堂上，你会（或不会）在课程设置、教学方法以及与学生及其家长的互动方面做些什么。
#
# *1B* - Apply each topic 2-5 reflexive posts based on 1A (4 x 400 words/excluding references). GTSD: 1.1.1, 1.3.1, 1.4.1, 1.5.1, 2.4.1, 4.1.1, 4.4.1, 7.1.1, 7.2.1
# - Topic 2: EAL/D Students
# - Topic 3: Culturally Relevant Pedagogy (CRP)
# - Topic 4: CRP in Action: What is 'Culture' Anyway?
# - Topic 5: CRP in Action: Linguistic Power and Diversity

# %%
for a course of Cultural Diversity – EAL/D Students, write an autobiographical essay, 420 words, based on: 
I have lived in both China and Australia for a long time. I spent my early life in China, and lived in seven cities, across south, east, west and north China over half year. After that, I moved to Sydney and completed my postgraduate studies. From primary school, middle school, to undergraduate university, postgraduate university, I studied at five different school. When I lived in China, I never see any schools handled variation in cultures or groups, as there were minor difference. I have see substantial diverse cultures when I travelled twenty countries, across China, Japan, Thailand, Malasiya, Indonesia, Cambodia, United States, Middle East, and eight European countries. From my experience, on average, people who live in places with more population migration are more open to see diversity. Those residents are more tendative to be respective to diversity and differentiation. 

Here is my model to deal with diversity or differentiation of groups. Given a mathematical set of all humankind as {1,2,...n...,N; 1 < n < N }, in which n is greater and 1 and less than N(The total number of human beings). n has many names, we call n as the school, company, club, community, city, state/province, country, continent, race, language-speaking, poor/rich, skin-color, religion-believer, or even western/eastern culture. We categrise any one person into huge number of small, but nonsense n. However, in this set {1,2,...n...,N}, apparently, only 1 and N deserve love, values, and special priority. I try to keep any n out of influencing my judgements. 

Imagine I was assigned to teach at a school, 这所学校有很多学生来自不同的文化、种族、社会经济和语言背景，其中许多背景与你自身不同。假设有三到五名新近移民的学生，他们母语流利，但在英语教学方面存在很大困难, what do I do in 在课程设置、教学方法以及与学生及其家长的互动方面。

My worldview has been deeply shaped by my substantial experience of different cultural landscapes. Having spent my early life in China, moving across seven distinct cities spanning the south, east, west, and north, I attended five educational institutions from primary school through to my undergraduate degree. In China, cultural variations were minor, and schools rarely dealt with group differentiation. My perspective changed fundamentally after migrating to Sydney for postgraduate studies and travelling to twenty countries across China, Japan, Thailand, Malaysia, Indonesia, Cambodia, United States, Middle East, and eight European countries. Witnessing substantial global diversity taught me that environments with high population migration foster residents who are more open, tentative, and respectful towards differences.

In order to navigate this complexity, I developed a mathematical model to conceptualise human diversity. If we define the all human population as a mathematical set {1,2,...n...,N; 1 < n < N }, where N represents universal humankind and 1 represents the unique one individual, while small n has many names such as school, company, club, community, city, state/province, country, continent, race, language-speaking, poor/rich, skin-color, religion-believer, or even western/eastern culture. In my view, these n categories are superficial groupings that can distort objective judgment. True value, love, and priority belong strictly to 1 (the individual) and N (our shared humanity). As an educator, I prevent the labels of any small n from biasing my pedagogical expectations.

If I was assigned to a diverse school with three to five newly arrived EAL/D students who are fluent in their first language but struggle with instructional English, my mathematical model guides my teaching practice. Instead of viewing these students through a deficit-based label (n), I will focus on their individual identity (1) and shared humanity (N).

In curriculum design and teaching methodology, I will implement more physical, plurilingual strategies that honour their individual cognitive capabilities. I will scaffold learning using visual aids, bilingual glossaries, and collaborative tasks, allowing them to utilise their strong first-language foundations as a bridge to English. To ensure inclusion in our shared classroom community, I will integrate culturally responsive resources. Finally, my interactions with students and parents will be grounded in deep respect. I will utilise translation technologies or even bicultural support workers to ensure parents are active partners in education, moving past linguistic barriers to motivate the unique potential of every learner.

# %%
Applying Topic 2: EAL/D Students. write reflexive post (400 words/excluding references) based on my autobiographical essay
- and a fact that across Australia, around 25 per cent of primary and secondary school students learn English as an additional language or dialect. However, in some schools this figure can be as high as 90 per cent. There are complexities for Aboriginal and Torres strait Islander Students as EAL/D Learners. At school the 'racial and 'cultural' identiities of all students are constantly negotiated and understand the implications for student identity formation of clasroom teacher actions or not.
- What does it mean to be 'other' in schools? Schools are where students' 'racial' and 'cultural' identities are constantly negotiated and that what teachers do (or not) can have serious implications for students' identity formation processes
- insert 5 reference APA 7th edition

EAL/D Learners and Identity Formation
My autobiographical reflections on living in multiple Chinese cities, migrating to Sydney, and multi-countries travelling highlight a major realisation: contexts with high population mobility usually bring about a greater openness to diversity. However, in my proposed mathematical model, I isolate the individual (1) and universal humanity (N) while treating intermediate groups (n) like race, dialect, or country as "nonsense" variables to prevent bias. All of these require deep, reflexive investigations when applied to English as an Additional Language or Dialect (EAL/D) learners.

Across Australia, approximately 25 per cent of primary and secondary school students are EAL/D learners, and this ratio could rapidly increase to as high as 90 per cent in specific localised school communities (Australian Curriculum, Assessment and Reporting Authority [ACARA], 2022). In these densely diverse classrooms, pretending that every student's cultural or linguistic background doesn't matter can actually make them feel excluded. While a colorblind approach intends to ensure equity, it transparently treats the classroom as a monolingual, monocultural baseline. Consequently, treating non-standard Australian English as wrong or something to be fixed, that is not a valid framework for building a quality learning environment.

When a student is positioned as the ‘other’ at school, their native language and cultural ways of thinking basically become invisible, or worse, they get treated as a cognitive deficit. Classrooms are highly contested spaces where kids are constantly navigating and negotiating their racial and cultural identities (D'Warte, 2014). What we do as teachers—or what we actively choose to ignore—has huge consequences for how these students form their sense of being self. For example, if I completely erase those intermediate group categories (n) from my mind in the name of being "blind to difference", I’ll completely miss the unique linguistic complexities of Aboriginal and Torres Strait Islander students who speak Aboriginal English. Because Aboriginal English is structurally unique, people frequently miscategorise it as just "broken English" instead of treating it as a legitimate dialect (Hertzberg, 2012). When we fail to validate that dialect for First Nations EAL/D learners, we changed their identity and just keep reinforcing old colonial dynamics.

That’s why EAL/D teaching has to move past trying to neutralise differences. We need an asset-based framework that actually brings out and uses a student’s full plurilingual toolkit (Sellwood & Harrison, 2022). Instead of erasing those mid-level cultural backgrounds (n), we need to put them front and centre using intentional scaffolding, open classroom discussions, and translanguaging strategies (Ahmed, 2018). In my own practice, I can’t just love some abstract idea of a student (1); I have to intentionally validate the real, everyday linguistic realities (n) that shape how they actually understand their world.

References
Ahmed, S. (2018). Being the change: Lessons and strategies to teach social comprehension. Heinemann.
Australian Curriculum, Assessment and Reporting Authority. (2022). English as an Additional Language or Dialect teacher resource: Overview and EAL/D learning progression.
D'Warte, J. (2014). Exploring linguistic repertoires: Multiple languages and literacy practices in mainstream classrooms. Australian Journal of Language and Literacy, 37(3), 154–168.
Hertzberg, M. (2012). Teaching English language learners in mainstream classes. Primary English Teaching Association Australia (PETAA).
Sellwood, J., & Harrison, N. (2022). Learning and teaching in Aboriginal and Torres Strait Islander education (4th ed.). Oxford University Press.

# %% [markdown]
# Applying Topic 3: Culturally Relevant Pedagogy (CRP) **keywords?? main concepts in Topic 3??** write reflexive post (400 words/excluding references) based on my autobiographical essay
# - What is Culturally Relevant Pedagogy? How is CRP related to my teaching context? What are the advantages/challenges of applying Culturally Relevant Pedagogy in my teaching? Why?
# - insert 5 reference APA 7th edition
#
# Applying Topic 4: CRP in Action: What is 'Culture' Anyway? **keywords?? main concepts in Topic 4??**write reflexive post (400 words/excluding references) based on my autobiographical essay.
# - What do you consider culture to be? Do you identify with one or more cultural groups? How? What do you think are the key elements needed for CRP to be actioned within a classroom setting? What if any challenges do you forsee in actioning CRP within your classroom or school setting.
# - insert 5 reference APA 7th edition
#
# Applying Topic 5: CRP in Action: Linguistic Power and Diversity **keywords?? main concepts in Topic 5??**write reflexive post (400 words/excluding references) based on my autobiographical essay
# - What is meant by Linguistic Power and Diversity when it is associated with CRP? Can the concepts of Linguistic Power and Diversity help challenge notions of "Other" within the classroom? How? Under what circumstances?
# - insert 5 reference APA 7th edition

# %% [markdown]
# #### Assessment 2 - Lesson Plan

# %% [markdown]
# PART A: Culturally inclusive lesson plan - to modify it 修订模式 (300 words)
# - Set up: imagined classroom include >3 EAL/D students, preferably with differing backgrounds, for whom you will have to implement various language support strategies.
# - You will need to align plan changes to accommodate students' English language competency, in which you must identify and describe the level of their English language proficiency using the [EAL/D Learning Progression descriptors of ACARA, 2015](https://docs.acara.edu.au/resources/EALD_Learning_Progression.pdf).
#
# PART B: Explanatory Essay (1700-word) - explain why the particular changes to the lesson plan have been made:
# - indicate you have obtained the lesson plan from an internet source, at the beginning of your assignment.
# - to take into account the backgrounds of your EAL/D students and their English language proficiency,
# - consider: (a) representation of diversity, (b) integration of various languages and dialects of English, and (c) integration of explicit linguistic scaffolding.
# - Identify and discuss the *pedagogy* (e.g. Culturally Responsive Pedagogy and/or Genre Pedagogy, CRPGP) and/or *pedagogical tools* (e.g. Intercultural Understanding, IU) you have used in order to justify the changes you have made to the lesson plan.
#
# writing:
# - Introduction (125 words)
# - background and Classroom Context (150 words) a brief discussion of the classroom context, describe the level of English language proficiency of the EAL/D students, using the EAL/D learner progression descriptors, as well as the *sociocultural mix??* of your broader classroom. You also need to preview the  pedagogy and/or pedagogies and/or pedagogical tools (citations!) you have drawn upon in order to make changes to your lesson plan (see below).
# - Representation of diversity (400 words)  identify and describe the changes you have made to the original lesson plan to address the representations of diversity in the classroom; identify and discuss the CRPGP and IU (citations!) that explain/help to justify the changes you have made to the lesson plan.
# - Integration of various languages and/or dialects of English (400 words) identify and describe the changes you have made to the original lesson plan to address the integration of various languages and dialects of English; then relate/justify your changes w.r.t the relevant CRPGP and/or IU (citations!).
# - Integration of explicit scaffolding (400 words) identify and describe the changes you have made to the original lesson plan to address the integration of explicit linguistic scaffolding into your lesson plan; then relate/justify your changes w.r.t the relevant CRPGP and/or IU (citations!).
# - Conclusion (125 words);
# - References (at least ten (10) unit readings)

# %% [markdown]
# ### EDCX513 Aboriginal Education

# %% [markdown]
# #### Contents

# %% [markdown]
# - [513 Schedule - Due](https://mylearn.une.edu.au/mod/book/view.php?id=3556474)
# - Indicate **EDCX513** at the top of each assessment
#
# PREXConnex - GTSD 2.4.1 Demonstrate broad knowledge of, understanding of and respect for Aboriginal and Torres Strait Islander histories, cultures and languages. During weeks 3 and/or 4 of your EDUC550 professional experience you will have a dialogue with the supervising teacher to:
# - Identify if there is a school-wide process / activity / resource for developing curriculum that is relevant and inclusive of Aboriginal students.
# - Ask the supervising teacher or colleague to share how they develop curriculum that is relevant and inclusive of Aboriginal and Torres Strait Islander cultures, and also share any programming that demonstrates relevance and inclusivity.

# %% [markdown]
# - Topic 4: Aboriginal Education Policy: Partnerships; Supportive learning environments
# - Topic 5: Aboriginal Education Policy: Engaging Aboriginal students; Aboriginal English
# - Topic 6: Aboriginal Languages; Culturally valid assessment
# - Topic 7: Teaching English literacy, numeracy & mathematics
#     - I recap some of the key ideas from Topics 5/6 including **Culturally Responsive Pedagogy(CRP)**, Aboriginal English(es) in the Classroom and Culturally Valid Assessment.
#     - I highlight the importance of reading and writing across the curriculum, and suggest with refernce to Harper et al., (2020) that we should provide explicit instruction for Aboriginal and Torres strait Islander students.
#     - I then use an example of a chemistry experiment in which I indicate how  the language of chemistry can be broken down, built up and then scaffolded with images and/or ideas from student lived experience to aid understanding and comprehension.
#     - Finally we consider the importance of student and community lifeworlds as the platform for building numeracy and mathematical knowledge for students.
# - Topic 8: Aboriginal Perspectives & Anti-racism

# %% [markdown]
# #### Assessment 1A - Three Posts/Reflections (3 x 150 words) + Summary (750 words)

# %%
Topic 1: Current Policies in Aboriginal Education
write reflection post (150 words//excluding references) to answer questions based on my background; insert 2 reference APA 7th edition
- What do you know about Aboriginal history and culture and Aboriginal Education?
- How might your experiences and assumptions affect your teaching?
- What are the current key policies for Aboriginal Education?
- my knowledge about Aboriginal history, culture, and Aboriginal Education is limited. But I have seen lots of culture diversity and groups differentiation, as I have lived in both China and Australia for a long time. I spent my early life in China, and lived in seven cities, across south, east, west and north China over half year. After that, I moved to Sydney. My family, two kids, my wife and me, loves travelling, and travelled to twenty countries, across China, Japan, Thailand, Malasiya, Indonesia, Cambodia, United States, Middle East, and eight European countries. I have seen substantial diverse cultures in travelling. 


I grew up in China and lived across seven diverse cities, followed by migrating to Sydney and travelling to twenty countries with my family - two kids and my wife - has profoundly shaped my worldview. While my direct knowledge of Aboriginal history, culture, and Aboriginal Education is not broad, these extensive cross-cultural experiences have instilled in me a deep appreciation for cultural diversity and group differentiation.

However, I must recognise that viewing Indigenous education through a generalised "multicultural" lens can be problematic. My assumption that global cultural awareness translates seamlessly to the Australian context may overlook the unique, sovereign histories and ongoing systemic inequalities faced by First Nations peoples.

To teach effectively, I shall align my practice with current key policies at both Federal and State level like the National Agreement on Closing the Gap, which explicitly mandates a shift toward Indigenous self-determination and co-designing educational outcomes (First Nations Education Council, 2024). Moving forward, I am committed to engaging with frameworks like the Aboriginal Cultural Standards Framework to actively foster a culturally safe, responsive classroom that honours the distinct rights of Aboriginal students (Department of Education Western Australia, 2015).

References
Department of Education Western Australia. (2015). Aboriginal Cultural Standards Framework. https://www.education.wa.edu.au/
First Nations Education Council. (2024). National Agreement on Closing the Gap: Annual report on education targets. Australian Government. https://www.closingthegap.gov.au/

# %%
Topic 2: Pre-Contact & First-Contact Aboriginal History
write reflection post (150 words//excluding references) to answer questions based on my background
- What are some notable features of pre-contact Aboriginal societies and cultures?
- What types of first-contact relations were there between Aboriginal and non-Aboriginal peoples in Australia?
- With **reference to the lectures and a critical approach to Harrison**, what is **cultural essentialism** and why is care needed in making assumptions about how Aboriginal students learn?
- Cultural essentialism is the practice of categorizing groups of people within a culture, or from other cultures, according to essential qualities
- insert 3 reference APA 7th edition, including: 
‘prehistory’ and ‘prehistoric’ will be used as in the original text; and with an acceptance that these terms have been used only to refer, in the strict definitional sense, ‘to a period antecedent to writing’ (Langton & Megaw, 1999).
Harrison, N. & Sellwood, J. (2022). Learning and Teaching in Aboriginal and Torres Strait Islander Education, 4th Edition. Oxford University Press Australia & New Zealand.


From the second topic about pre-contact and first-contact Aboriginal history, I learned that before European invasion, the Aboriginal societies were highly sophisticated, defined by rich oral traditions, complex kinship structures, and deep spiritual connections to the land. While often viewed through the narrow lens of a period "antecedent to writing" (Langton & Megaw, 1999), these societies relied on intricate, enduring knowledge-sharing systems. First-contact relations varied substantially across Australia, ranging from brief, curiosity-driven barter and strategic diplomacy to violent dispossession, frontier warfare, and systematic exclusion.

In today's teaching practices, educators must critically engage with Harrison and Sellwood (2022) to avoid cultural essentialism — the practice of categorising individuals within a culture based on fixed, "essential" qualities. For example, essentialising Aboriginal students by assuming they are all "visual or hands-on learners" ignores their vast individual diversities. From our lectures, I have realised that treating students as uniform cultural archetypes will erodes customised teaching, masks distinct individual needs, and reinforces harmful stereotypes rather than fostering authentic inclusion in our education system.

References
Harrison, N., & Sellwood, J. (2022). Learning and teaching in Aboriginal and Torres Strait Islander education (4th ed.). Oxford University Press.
Langton, M., & Megaw, J. V. S. (1999). Expressions of interest: Defining the pre-contact past. Australian Archaeology, 49(1), 23–31.
University of New South Wales. (2026). Aboriginal education and inclusive pedagogies [Lecture notes]. Moodle. https://moodle.telt.unsw.edu.au/

# %%
Topic 3: Aboriginal Australian History
write reflection post (150 words/excluding references) to answer questions based on my background:
- Outline the effects on Aboriginal Education in NSW of past government actions and policies, with **reference to assimilation and resistance**.
- How might the effects of that history influence the ways in which Aboriginal students learn and non-Aboriginal teachers teach?
- insert 3 reference APA 7th edition, including:
Harrison, N. & Sellwood, J. (2022). Beginning teachers in Aboriginal and Torres Strait Islander Education (Chapter 1). In Learning and teaching in Aboriginal and Torres Strait Islander Education (4th ed., pp. 2-21). South Melbourne: Oxford University Press.


From the third topic regarding Aboriginal Australian history, I learned that the past government policies in New South Wales, particularly enforced assimilation and the systematic removal of children, severely disrupted Aboriginal languages, cultures, and their community-oriented education. Yet, this history is also defined by Aboriginal resistance, in which some communities consistently fight to preserve their identity and demand for educational self-determination.

This enduring history deeply influences modern classrooms and our teaching. It is obvious that the intergenerational trauma from forced exclusion often come up as deep-seated institutional mistrust, which impact Aboriginal students' engagements and learning within mainstream Western systems. Conversely, non-Aboriginal teachers often struggle with an "anxiety of teaching," fearing they will cause cultural offense or misrepresent Indigenous perspectives (Harrison & Sellwood, 2022). To overcome this, teachers shall move past historical defensiveness, critically examine their own biases, and build genuine, trauma-informed relationships in teaching practice. By recognising that resistance is an ongoing demand for respect, educators can transform their teaching into a culturally safe, collaborative practice.

References
Aboriginal Educational Consultative Group [AECG]. (2021). The legacy of NSW Aboriginal education: From assimilation to self-determination. NSW AECG Inc.

Harrison, N., & Sellwood, J. (2022). Beginning teachers in Aboriginal and Torres Strait Islander Education (Chapter 1). In Learning and teaching in Aboriginal and Torres Strait Islander Education (4th ed., pp. 2–21). Oxford University Press.

NSW Department of Education. (2020). Aboriginal Education Policy. NSW Government. https://education.nsw.gov.au/

# %% [markdown]
# Reflective summary of 3 units learning (750 words/excluding references):
# - Use 3 posts above as a starting point, discuss the way I have engaged with the unit content and knowledge.
#     1. A description of my learning (a reflection, not a repetition of the three module posts).
#     2. A discussion of my thoughts and feelings
#     3. An analysis of my learning in the unit
#     4. A conclusion identifying possible gaps in my knowledge
#     5. An action plan, outlining the way in which you will apply my knowledge and learning to my future profession, further study and/or personal life.
#     6. >6 reference APA 7th edition
#
# Engaging with Aboriginal Education and Cultural Frameworks
#
# Introduction and Description of Learning
# Engaging with these three modules has provided a structured yet challenging pathway for re-evaluating my role as a future educator in Australia. Initially, my understanding of Aboriginal history, culture, and Aboriginal Education was limited. My educational background and formative years were spent in China, where I lived across seven distinct cities spanning the southern, eastern, western, and northern regions. This early exposure to vast regional differences, combined with migrating to Sydney and travelling to twenty countries across Asia, Europe, and the Middle East with my wife and two children, shaped what I believed was a robust, globally-minded appreciation for cultural diversity.
#
# However, the unit content forced me to look beyond this generalized framework. Through exploring pre-contact societies, the brutal realities of first-contact history, and the intergenerational trauma inflicted by NSW assimilation policies, I learned that Australian Indigenous education cannot simply be treated as another branch of multiculturalism. I moved from an superficial awareness of "group differentiation" to a deeper understanding of the unique, sovereign rights, enduring resistance, and distinct systemic educational challenges faced by Aboriginal and Torres Strait Islander peoples.
#
# [Personal Background: Global/Multicultural Perspective]
#                          │
#                          ▼ (Disrupted by Unit Content)
# [Critical Frameworks: Local Anti-Essentialist Pedagogy]
#                          │
#                          ▼ (Professional Realization)
# [High-Expectations Relationships & Cultural Safety (AITSL 1.4/2.4)]
#
# Discussion of Thoughts and Feelings
# Confronting the realities of historical assimilation policies and their modern educational legacies evoked a strong sense of professional anxiety. As a migrant teacher, I initially felt an acute "anxiety of teaching" (Harrison & Sellwood, 2022), worrying that my lack of deep, lifelong immersion in Australian history would lead me to misrepresent Indigenous perspectives or inadvertently cause offense.
#
# Crucially, learning about cultural essentialism shifted my perspective. I felt a sense of relief mixed with heightened responsibility when I realized that treating Aboriginal students as a uniform monolith—such as assuming they all share identical "visual" or "hands-on" learning styles—is itself a form of reductive stereotyping. My travels taught me that human communities are beautifully complex; the unit content grounded this by showing me that Aboriginal identity is diverse, dynamic, and deeply personal. I realized that my fear of teaching Indigenous content stemmed from my own assumptions, and that genuine teaching begins with humility, active listening, and a willingness to learn alongside my students.
#
# Analysis of Learning
# A critical analysis of my learning reveals a significant conceptual evolution: the rejection of a "deficit" or "essentialist" mindset in favour of a relational, contextual approach. In my second reflective post, I engaged with the dangers of categorizing individuals based on fixed cultural traits (Harrison & Sellwood, 2022). My international experiences initially led me to look for broad cultural patterns to navigate new environments. However, applying this to the classroom risks reinforcing structural inequalities.
#
# Furthermore, analyzing past government actions highlighted the structural barriers embedded within Western educational systems. Enforced assimilation historically weaponized schooling to erase culture, a practice met with fierce, sustained Aboriginal resistance. This resistance continues today as a demand for self-determination in education. Understanding this history clarifies why some Aboriginal families maintain a justified institutional mistrust towards schools. Therefore, my cross-cultural empathy is insufficient on its own; it must be coupled with structural awareness and alignment with modern frameworks like the National Agreement on Closing the Gap, ensuring that my pedagogy actively supports Indigenous self-determination and cultural safety.
#
# Conclusion and Gaps in Knowledge
# While this unit has fundamentally reshaped my educational philosophy, notable gaps remain in my knowledge. My understanding of local Aboriginal histories, particularly the specific language groups and stories of the Epping and wider Sydney Basin areas where I live and teach, remains limited. Additionally, while I comprehend the theoretical necessity of avoiding essentialism, I still lack practical confidence in selecting and evaluating authentic, community-approved First Nations resources for daily lesson planning. I need to bridge the gap between understanding macroeconomic and policy-level frameworks, like Closing the Gap, and implementing micro-level, culturally responsive teaching strategies in the classroom.
#
# Action Plan
# To translate this learning into professional and personal practice, I will implement a three-part action plan:
#
# Professional Practice: In my future classroom, I will actively counter cultural essentialism by adopting a personalized, strengths-based approach to every student. I will design a culturally safe environment by embedding local Indigenous perspectives into the curriculum naturally, rather than as an isolated, tokenistic topic.
#
# Further Study and Local Engagement: I will explicitly learn about the Traditional Custodians of the land where I teach. I will engage with local Aboriginal Educational Consultative Groups (AECG) and access professional development through NESA to learn how to appropriately consult with local communities and Elders.
#
# Personal Life: I will continue travelling and exploring with my family, but with a refined focus. Our future travels within Australia will purposefully include visiting Indigenous cultural centres and historical sites, ensuring my children and I build a grounded, respectful understanding of the oldest continuous living culture on Earth.
#
# References
# Aboriginal Educational Consultative Group [AECG]. (2021). The legacy of NSW Aboriginal education: From assimilation to self-determination. NSW AECG Inc.
#
# Department of Education Western Australia. (2015). Aboriginal Cultural Standards Framework. https://www.education.wa.edu.au/
#
# First Nations Education Council. (2024). National Agreement on Closing the Gap: Annual report on education targets. Australian Government. https://www.closingthegap.gov.au/
#
# Harrison, N., & Sellwood, J. (2022). Learning and teaching in Aboriginal and Torres Strait Islander education (4th ed.). Oxford University Press.
#
# Langton, M., & Megaw, J. V. S. (1999). Expressions of interest: Defining the pre-contact past. Australian Archaeology, 49(1), 23–31.
#
# NSW Department of Education. (2020). Aboriginal Education Policy. NSW Government. https://education.nsw.gov.au/

# %% [markdown]
# #### Last step: edit docx - Assessment 1B - Policy Analysis(800 words)

# %% [markdown]
# - 1 Use Generative AI to formulate an answer to all of the forum questions from a chosen Topic **(I chose 7 from topic 4-8)**.
# - 2 Critically analyse the Generative AI response according to the Aboriginal Education Policy and its associated policy documents.
#
# Topic 7: Teaching English literacy, numeracy & mathematics - Online questions  [+ AI Prompt Questions]
# - What strategies may effectively meet the literacy, numeracy and/or mathematical learning needs of Aboriginal and Torres Strait Islander students in your chosen subject area or KLA (Key Learning Area)?
# - How can Indigenous knowledges be incorporated into teaching in your chosen subject area in a culturally responsive way.
# - How might you address issues of cultural safety when teaching to meet the literacy, numeracy and/or mathematical learning needs of Aboriginal and Torres Strait Islander students? Similarly what do you need to do to incorporate Indigenous knowledges within your lesson planning in a culturally safe way?
#
# two separate documents = Generative AI responses + your analysis (800 words) consider/refer to the following:
# 1. NSW Department of Education(DoE) Aboriginal Education Policy  (2008,V04.1.1 last updated 16-09-2025),
# 2. NSW DoE and NSW AECG Partnership Agreement 2020-2030.
# 3. NSW DoE 2022 Stronger Strides Together.
# 4. NSW DoE Anti-Racism Strategy 2024-2035.
# 5. Australian Government (2015) National Aboriginal and Torres Strait Islander Education Strategy.
# 6. Australian Human Rights Commission (AHRC) (2024) National Anti-Racism Framework.
# 7. Australian Curriculum and Assessment Authority (ACARA) n.d. Australian Cross-Curriculum Priorities: Aboriginal and Torres Strait Islander Histories and Cultures ; and
# 8. Other relevant and up to date academic literature, including audio-visual and other resources included in Topic notes and Lectures.

# %% [markdown]
# #### edit source file - Assessment 2 - Unit Plan & Rationale(2k words)

# %% [markdown]
# PART A . (700 + words)
# - a **Unit Plan** for teaching Mathematics in Stage 5 aligned with the NSW syllabus content and outcomes
#     - outline 6 lesson sequence, embed Indigenous knowledges into it, demonstrate the teaching and learning strategies you will use to enhance the engagement and learning of Aboriginal students within your classroom.
#     - [NSW NESA provides some foundational guidance regarding unit preparation here](https://curriculum.nsw.edu.au/use-the-curriculum/planning-supporting-student-learning/selecting-sequencing#units)
#
# PART B. (700+ word)
# - develop a detailed **lesson plan** from Part A.
# - include the key resources, specific teaching and learning strategies, appropriate community engagement actions that you will use to deliver the lesson.
#     - clearly meet >=1 syllabus outcomes in Part A; and support >=1 key commitments of the NSW Aboriginal Education Policy.
#
# PART C. (600 words)
# - A **rationale** for the content choices you have made in PART A and B
#     - describe how these choices have worked to embed Indigenous knowledge within the Unit of Work/detailed lesson and/or support Aboriginal student engagement and learning within your classroom.
# - The rationale should make reference to the commitments of the NSW Aboriginal Education Policy, relevant pedagogy, appropriate teaching and learning strategies and notions of cultural safety, and community partnerships.

# %% [markdown]
# ### EDUC540 Classroom Management & Research (Online PrEx 10 days)

# %% [markdown]
# #### Assessment

# %% [markdown]
# Assessment 1 (10%): **9 Forum Postings each week**, each >110 words, each module comprising TWO Forum Postings  (content + observation)
#
# Assessment 2 (40%): Reflective Observational Analysis出題有病寫幾百頁出一個題目
# - I chose TASK 2 (1500 words)
# - 直接去Assessment 2 **Task Information Book** 先看前面8頁; 然後看[Task 2](https://mylearn.une.edu.au/mod/book/view.php?id=3539678&chapterid=1045484#mod_book-chapter) in the Book 3視頻（year 7）寫分析 - include a title page with you name, student number and word count.
#     - Summarise your results by making a comparison between the two teachers in the videos.
#     - What are their strengths and what behaviours are not evident that SHOULD be included or considered?
#     - In discussion, you should refer to all strategies including non verbal established rules and routines for the beginning and end of lessons, for learning activities and for transitions (so far 700 words)
#     - Discuss: What does the literature suggest these teachers did that was effective? (800 words)
# - Purpose:
#     1. demonstrate knowledge and understanding of research into how students learn, including knowledge of child and adolescent development, and the implications for teaching by observing recordings of teacher practice, gathering data, analysing, evaluating findings informed by current research literature, and synthesising knowledge of effective teacher practice (GTSD 1.1.1, 1.2.1);
#     3. demonstrate understanding of a range of teaching strategies including verbal and non-verbal communication to support student engagement by observing teacher practice, and critiquing in terms of current research literature (GTSD 3.3.1, 3.5.1).
#
# Assessment 3 (50%) - Formal written task - Applied research, use my unit plan “computation and economics”
# - Introduction (100 words - 5%)
#     - Establish an argument for the need to consider classroom management strategies when beginning with a new class, and planning a unit of work.
#     - Demonstrate your understanding of the efficacy and applications of proactive practices that prevent misbehaviour through high-quality instruction.
# - Context and description of unit (50 words - 2%)
#     - Provide a short description of the context, including the year level, and the unit of work selected for this assignment.
# - Quality Learning Environment (600 words – 30%)
#     - What things will you need to consider as you begin your year with a new class of students, to ensure that you create a Quality Learning Environment? How will you make sure your students understand what your expectations are? Describe THREE strategies, how you would implement them within your chosen context, and justify their selection using evidence from the literature. Identify at least TWO AITSL Standards (https://www.aitsl.edu.au/standards) you will meet by using these strategies.
# - Intellectual Quality and Significance (1000 words – 45%)
#     - What things will you need to consider as you plan your unit of work to make sure that your students are motivated and successful? Describe FOUR strategies, how you would implement them within the context of your unit, and justify their selection using evidence from the literature. Identify at least TWO AITSL Standards you will meet by using these strategies.
# - Assessing success (200 words - 10%)
#     - How will you know whether or not the strategies you have selected worked, both in terms of classroom management and student achievement. Describe TWO strategies, how you would implement them, and justify their selection using evidence from the literature.  Identify at least ONE AITSL Standard you will meet by using these strategies.
# - Conclusion (50 words - 2%)
#     - Bring everything you have presented here back to the focus of this unit – classroom management.
# - Presentation and referencing (6%): >five peer-reviewed APA references to justify your choice of strategies.
# - Submit Unit Plan as an appendix.

# %% [markdown]
# #### Learning outcomes

# %% [markdown]
# - demonstrate knowledge and understanding of research into how students learn, including knowledge of child and adolescent development, and the implications for teaching by observing recordings of teacher practice, gathering data, analysing, evaluating findings informed by current research literature, and synthesising knowledge of effective teacher practice (GTSD 1.1.1, 1.2.1);

# %% [markdown]
# - demonstrate knowledge and understanding of the concepts, substance and structure of the content and teaching strategies of teaching areas (including literacy and numeracy in primary and secondary contexts), by observing teacher practice, and critiquing in terms of current research literature (GTSD 1.5.1, 2.1.1);

# %% [markdown]
# - demonstrate understanding of a range of teaching strategies including verbal and non-verbal communication to support student engagement by observing teacher practice, and critiquing in terms of current research literature (GTSD 3.3.1, 3.5.1);

# %% [markdown]
# - identify, observe and critique practising teachers’ strategies to support inclusive student participation, engagement in classroom activities, the management of challenging behaviours, and implications for mental health, informed by research literature (GTSD 4.1.1, 4.2.1, 4.3.1, 4.4.1);

# %% [markdown]
# - demonstrate understanding of the purpose of providing timely and appropriate feedback to students about their learning by observing teacher practice, and critiquing in terms of current research literature (GTSD 5.2.1);

# %% [markdown]
# - demonstrate an understanding of the sources of professional learning, a rationale for continued professional learning and the implications for improved student learning by engaging in collaborative professional learning processes (GTSD 6.2.1, 6.4.1, 7.4.1).

# %% [markdown]
# #### Module 0 - one post done

# %% [markdown]
# - Inclusive practice
# - Behaviour support strategies
#
# Difficult behaviours & Classroom management
# - 2001 <British Journal of Special Education>: "Special Needs in the Twenty-First Century: Where We’ve Been and Where We’re Going" by Alan Dyson is a foundational text in educational theory.
#     - The Core is "Dilemma of Difference", in which society desires to treat all learners as essentially the same (promoting equality and shared human rights) and an equal, opposite pressure to treat them as different (identifying individual deficits to allocate special resources).
#     - Where We've Been: The Shift from Segregation (medical model) to Inclusion
#     - Where We're Going: Broadening to "Social Inclusion"
# - "School-Wide Positive Behavior Interventions and Supports and Academic Achievement": SWPBIS is a systems-level, applied behavior analysis approach designed to build a positive school culture
#     - focuses on preventing problem behaviors, explicitly teaching and reinforcing expected behaviors, providing instructional consequences for misbehavior, using multiple tiers of intervention intensity, and utilizing data-driven decision-making
# - "A major shift from intervention to prevention" is about Classroom Management, and its transition about how educators perceive and manage student behavior

# %% [markdown]
# #### Module 1: Quality Learning Environments - two posts done

# %% [markdown]
# A. Theories of classroom management
# - a). behaviour management, b). effective teaching practices
# - PBL (Positive Behaviour for Learning) & PBS (Positive Behaviour Support)
# - Quality Teaching Model (QTM)
#   - Intellectual Quality
#   - Quality Learning Environment
#   - Significance
#
# B. Assessment for Learning (AFL)学习评估
# - Formative assessment - narrative observation & focused narrative observation

# %% [markdown]
# Post 3
# Narrative/descriptive observation
# - Watch the video - Stage 5 Science lesson (FIRST 20 MINUTES only). Write down what you see; describe the lesson as you see it unfold. Do not make judgements, be objective.
# - An example of a narrative description:9am - Start of lesson, T getting S’s sitting properly on mat. Reading time. Got book out. T reminded John to sit with legs crossed. John does this. T says well done. T starts reading. Good class engagement. S’s find story interesting. T keeps reading book, little off-task by S’s. 10 minutes finish book. Janet hand up, asks question about book. T praise for good question. Kim pushes Karen. T did not notice as back turned to respond to Janet. Karen pushes Kim back. T gives instructions to S for activity. End lesson. 9.15am
#
# Focused narrative/descriptive observation
# - focused on a particular situation, student or behaviour.
# - This classroom has a sign on the wall that says to put your hand up only if you want to ask a question. That is because the teacher wants to use another strategy to allow MORE students to answer/participate in the discussion. The way she does this is to ask a student to choose a number and then she asks that student with the corresponding number to answer. However, the teacher does not do this all of the time. Watch the same 20 minutes of video again and record what you see and this time keep in mind a focus on how the teacher asks questions.

# %% [markdown]
# #### Module 2
